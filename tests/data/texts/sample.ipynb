# %%
from raggify.logger import logger, configure_logging

configure_logging()

logger.info("hello from raggify!")
# Out:
# INFO: 2025-12-14 06:15:10,784 raggify hello from raggify! @ /tmp/ipykernel_616202/1582768302.py:5 <module>
